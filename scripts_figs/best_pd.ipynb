# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as mcolors
from matplotlib import rc
import matplotlib.gridspec as gridspec
from fonts_config import set_computer_modern, truncate_colormap
set_computer_modern()
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from PIL import Image
from matplotlib.colors import LogNorm
from matplotlib.animation import FuncAnimation, FFMpegWriter
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# %%
# ----------------------------------------------------------------------------
# Paths
# ----------------------------------------------------------------------------
n_best=1420
best=xr.open_dataset(f"/p/projects/megarun/luciagu/data/tabone2024/ensemble_reduced/{n_best}/yelmo2D_reduced.nc")
sim=best.sel(time=0)

# %%
 # Colormaps
colors = ["#ffffff", "#a8a8a8", "#000000"]

# Crear un colormap interpolado con 10 niveles
uxy_s_map = truncate_colormap(plt.get_cmap('gray_r'), minval=0, maxval=0.9)

zmap = mcolors.LinearSegmentedColormap.from_list("zmap", [
(0.0, "#204c6e"),
(0.499, "#6ab8cb"),
(0.50, "#024224"),
(1.0, "#b18b5d")
])

# %%
def pd_plot(ax,sim,uxy_s_map,zmap):
    xc=sim.xc
    yc=sim.yc
    z_bed=sim.z_bed*1e-3
    z_srf=sim.z_bed+sim.H_ice
    ice=xr.where((sim.f_grnd==1)&(sim.H_ice>0), 1, 0)
    log_uxy = sim.uxy_s.where(sim.H_ice>0) + 1e-8

    # Dibujar mapas
    bat = ax.pcolormesh(xc, yc, z_bed, cmap=zmap, vmin=-3, vmax=3)
    vel = ax.contourf(xc, yc, log_uxy, levels = np.logspace(0,3,10) ,  norm = LogNorm(), cmap = uxy_s_map,extend='both')
    # ice = ax.contourf(xc, yc, ice, colors=['White'],levels=np.linspace(0.5, 1.2, 2))

    # # Contornos
    cs1 = ax.contour(xc, yc, z_srf, levels=np.arange(150, 3600, 500), colors='black', alpha=0.3)
    cs2 = ax.contour(xc, yc, z_srf, levels=np.arange(150, 4150, 1000), colors='black')

    
    ax.set_title(f"Yelmox")
    ax.set_aspect(1)
    ax.tick_params(labelbottom=False, labelleft=False)
    return bat, vel

def diff_plot(ax,sim):
    obs = xr.open_dataset("/p/projects/megarun/ice_data/Greenland/GRL-8KM/GRL-8KM_TOPO-M17.nc")
    xc=sim.xc
    yc=sim.yc
    z_bed=sim.z_bed*1e-3
    z_srf=sim.z_bed+sim.H_ice
    diff = sim.H_ice.values - obs.H_ice.values

    # Dibujar mapas
    im_diff = ax.contourf(xc, yc, diff, levels=np.linspace(-1400,1400,10),cmap = "bwr",extend='both')

    # # Contornos
    cs1 = ax.contour(xc, yc, z_srf, levels=np.arange(0, 100, 1), colors='black',linewidths=0.4)

    
    ax.set_title(f"Ice thickness error")
    ax.set_aspect(1)
    ax.tick_params(labelbottom=False, labelleft=False)
    return im_diff

def obs_plot(ax,uxy_s_map,zmap):
    sim = xr.open_dataset("/p/projects/megarun/ice_data/Greenland/GRL-8KM/GRL-8KM_TOPO-M17.nc")
    obs_v = xr.open_dataset("/p/projects/megarun/ice_data/Greenland/GRL-8KM/GRL-8KM_VEL.nc")

    xc=sim.xc
    yc=sim.yc
    z_bed=sim.z_bed*1e-3
    z_srf=sim.z_bed+sim.H_ice
    log_uxy = obs_v.uxy_srf.where(sim.H_ice>0) + 1e-8

    # Dibujar mapas
    bat = ax.pcolormesh(xc, yc, z_bed, cmap=zmap, vmin=-3, vmax=3)
    vel = ax.contourf(xc, yc, log_uxy, levels = np.logspace(0,3,10) ,  norm = LogNorm(), cmap = uxy_s_map,extend='both')

    # # Contornos
    cs1 = ax.contour(xc, yc, z_srf, levels=np.arange(150, 3600, 500), colors='black', alpha=0.3)
    cs2 = ax.contour(xc, yc, z_srf, levels=np.arange(150, 4150, 1000), colors='black')

    
    ax.set_title(f"Observations")
    ax.set_aspect(1)
    ax.tick_params(labelbottom=False, labelleft=False)
    return bat, vel

# %%
fig = plt.figure(figsize=(14, 9))

gs = gridspec.GridSpec(2, 3,height_ratios=[3, 1])
#  H_ice ---------------------------------------------------------------------
ax1 = plt.subplot(gs[0, 0])
bed,vel=pd_plot(ax1,sim,uxy_s_map,zmap)

ax1 = plt.subplot(gs[0, 1])
obs_plot(ax1,uxy_s_map,zmap)

ax1 = plt.subplot(gs[0, 2])
err = diff_plot(ax1,sim)


# Legend and colorbars ------------------------------------------------------

# Leyenda

ax4 = plt.subplot(gs[1, 0])
ax4.axis('off')
axins = inset_axes( ax4,
width="55%",  
height="10%", 
loc="center",
bbox_transform=ax4.transAxes,
borderpad=0)
cb = plt.colorbar(bed, cax=axins, orientation='horizontal', ticks=[-3,-1.5,0,1.5,3],shrink=0.5)
cb.set_label('Bedrock elevation (m)')

ax4 = plt.subplot(gs[1, 1])
ax4.axis('off')
axins = inset_axes( ax4,
width="55%",  
height="10%", 
loc="center",
bbox_transform=ax4.transAxes,
borderpad=0)
cb = plt.colorbar(vel, cax=axins, orientation='horizontal',shrink=0.5)
cb.set_label('Surface velocity (m/yr)')

ax4 = plt.subplot(gs[1, 2])
ax4.axis('off')
axins = inset_axes( ax4,
width="55%",  
height="10%", 
loc="center",
bbox_transform=ax4.transAxes,
borderpad=0)
cb = plt.colorbar(err, cax=axins, orientation='horizontal',ticks=[-1000,0,1000],shrink=0.5)
cb.set_label('Ice thickness diff. (m)')

plt.subplots_adjust(
        left=0,   # Margen izquierdo
        right=1,  # Margen derecho
        top=0.95,    # Margen superior
        bottom=0,  # Margen inferior
        wspace=0,  
        hspace=0   
        )
plt.savefig("../figs/present_day.png",dpi=300)
# plt.close()
# Out:
# /tmp/ipykernel_2897806/161403607.py:21: UserWarning: Using the axes or figure transform requires a bounding box in the respective coordinates. Using bbox_to_anchor=(0, 0, 1, 1) now.
#   axins = inset_axes( ax4,
# /tmp/ipykernel_2897806/161403607.py:32: UserWarning: Using the axes or figure transform requires a bounding box in the respective coordinates. Using bbox_to_anchor=(0, 0, 1, 1) now.
#   axins = inset_axes( ax4,
# /tmp/ipykernel_2897806/161403607.py:43: UserWarning: Using the axes or figure transform requires a bounding box in the respective coordinates. Using bbox_to_anchor=(0, 0, 1, 1) now.
#   axins = inset_axes( ax4,

# %%
obs = xr.open_dataset("/p/projects/megarun/ice_data/Greenland/GRL-8KM/GRL-8KM_TOPO-M17.nc")

h1 = sim.H_ice
h2 = obs.H_ice
x = h1.values.flatten()
y = h2.values.flatten()
mask = np.isfinite(x) & np.isfinite(y)
x, y = x[mask], y[mask]
diff = sim.H_ice.values - obs.H_ice.values
rmse_H = np.sqrt(diff**2).mean()

# Crear figura
fig, ax = plt.subplots(figsize=(9, 9))

# Scatter plot
sc = ax.scatter(x, y, s=3, alpha=0.4, color="black")

# Línea identidad (y = x)
lims = [
    min(np.nanmin(x), np.nanmin(y)),
    max(np.nanmax(x), np.nanmax(y))
]
ax.plot(lims, lims, color="red", lw=5, label='y = x')
ax.text(100,3200, f"RMSE = {rmse_H:.1f}")

# Ejes y estilo
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_xlabel("YelmoX")
ax.set_ylabel("Observations")

plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()
